# %%
#navigate to correct folder
# !ls
# %cd CS449/Diffusion-Models-pytorch

# %%
#unzip the training dataset
import zipfile as zf
files = zf.ZipFile("train_conditional.zip", 'r')
files.extractall('train_folder')
files.close()

# %%
#clean the environment after training
import shutil
shutil.rmtree('dataConditional')#delete contents of given folder

# %%
#create a zip for the images that were generated
# %cd results
# !ls
# !zip -r results_unconditional_500.zip 'unconditional'
# Out:
# [Errno 2] No such file or directory: 'results'
# /home/jupyter/src/CS449/Diffusion-Models-pytorch/results
# DDPM_conditional  class2  class4  progress
# class1		  class3  class5  unconditional
#   adding: unconditional/ (stored 0%)
#   adding: unconditional/picture85.jpg (deflated 19%)
#   adding: unconditional/picture124.jpg (deflated 21%)
#   adding: unconditional/picture80.jpg (deflated 19%)
#   adding: unconditional/picture147.jpg (deflated 19%)
#   adding: unconditional/picture69.jpg (deflated 19%)
#   adding: unconditional/picture31.jpg (deflated 22%)
#   adding: unconditional/picture77.jpg (deflated 20%)
#   adding: unconditional/picture92.jpg (deflated 19%)
#   adding: unconditional/picture66.jpg (deflated 20%)
#   adding: unconditional/picture146.jpg (deflated 21%)
#   adding: unconditional/picture38.jpg (deflated 18%)
#   adding: unconditional/picture145.jpg (deflated 20%)
#   adding: unconditional/picture79.jpg (deflated 22%)
# ...
